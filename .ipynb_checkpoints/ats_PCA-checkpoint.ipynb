# %% [markdown]
# # <font color='green'>NEW: Trying PCA</font>

# %%
import numpy as np
from sklearn import decomposition, datasets
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# Load data from csv file
ats_data = np.genfromtxt(
    fname ='mydata.csv', delimiter= ',', dtype= float)

# %%
ats_data = np.delete(arr = ats_data, obj=0, axis = 0)

# %%
X = ats_data

# %%
X.shape
# Out:
# (5100, 36)

# %%
ats_data
# Out:
# array([[  46.,   40.,  119., ...,   31.,  131.,  142.],
#        [  47.,   37.,  119., ...,   29.,  133.,  143.],
#        [  80.,   95.,  100., ...,   83.,   96.,   74.],
#        ...,
#        [  68.,   75.,  108., ...,  100.,  104.,   85.],
#        [  71.,   87.,  108., ...,   91.,  104.,   85.],
#        [  71.,   91.,  100., ...,   91.,  100.,   81.]])

# %%
# Now standardize features

# %%
# create scaler object and fit the scaler to the features and transform
sc = StandardScaler()
X_std_pca = sc.fit_transform(X)

# %%
pca = decomposition.PCA(n_components=2)
X_std_pca = pca.fit_transform(X_std)

# %%
X_std_pca.shape
# Out:
# (5100, 2)

# %%
X_std_pca
# Out:
# array([[ -0.91600464,  14.4906449 ],
#        [ -0.68147236,  12.90320736],
#        [  0.18796229,   1.87017847],
#        ...,
#        [ -1.04902112,   1.70204883],
#        [ -1.05176978,   0.97470273],
#        [ -1.00997847,   0.72065466]])

# %%
xs = X_std_pca[:,0]
ys = X_std_pca[:,1]

# %%
plt.scatter(xs, ys, color=['red', 'blue'])
plt.show()
