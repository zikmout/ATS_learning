# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import KMeans
import sklearn.metrics as sm
 
import pandas as pd
import numpy as np
 
# Only needed if you want to display your plots inline if using Notebook
# change inline to auto if you have Spyder installed
# %matplotlib inline

# %%
cols = ["V1","V2","V3","V4","V5","V6","V7","V8","V9","V10","V11","V12","V13","V14","V15","V16","V17","V18","V19","V20","V21","V22","V23","V24","V25","V26","V27","V28","V29","V30","V31","V32","V33","V34","V35","V36"]

# %%
data = pd.read_csv('mydata.csv')
#data = data[1:]

# %%
stats = data.describe()
stats
# Out:
#                 V1           V2           V3           V4           V5  \
# count  5100.000000  5100.000000  5100.000000  5100.000000  5100.000000
# mean     73.092157    91.578431    99.568627    79.827059    72.957843
# std      11.876090    16.038819    15.611375    13.513639    11.772122
# min      41.000000    28.000000    62.000000    44.000000    42.000000
# 25%      64.000000    79.000000    87.000000    70.000000    64.000000
# 50%      71.000000    92.000000   101.000000    81.000000    71.000000
# 75%      84.000000   106.000000   113.000000    90.000000    83.000000
# max     104.000000   137.000000   139.000000   144.000000   104.000000
#
#                 V6           V7           V8           V9          V10  \
# count  5100.000000  5100.000000  5100.000000  5100.000000  5100.000000
# mean     91.425686    99.357843    79.643725    72.608039    90.861765
# std      15.823086    15.585557    13.447272    11.716109    16.071067
# min      29.000000    62.000000    46.000000    42.000000    29.000000
# 25%      79.000000    86.000000    69.000000    64.000000    79.000000
# 50%      92.000000   101.000000    81.000000    71.000000    91.000000
# 75%     106.000000   113.000000    90.000000    83.000000   104.000000
# max     137.000000   139.000000   157.000000   104.000000   130.000000
#
#           ...               V27          V28          V29          V30  \
# count     ...       5100.000000  5100.000000  5100.000000  5100.000000
# mean      ...         99.244902    79.695686    72.590588    91.187843
# std       ...         15.721836    13.749900    11.815466    15.915964
# min       ...         60.000000    44.000000    41.000000    27.000000
# 25%       ...         86.000000    69.000000    64.000000    79.000000
# 50%       ...        101.000000    81.000000    71.000000    91.500000
# 75%       ...        113.000000    90.000000    83.000000   104.000000
# max       ...        139.000000   151.000000   104.000000   130.000000
#
#                V31          V32          V33          V34          V35  \
# count  5100.000000  5100.000000  5100.000000  5100.000000  5100.000000
# mean     99.207451    79.615294    72.357647    90.856667    98.984510
# std      15.735910    13.626149    11.711489    15.921349    15.712095
# min      62.000000    42.000000    40.000000    27.000000    50.000000
# 25%      86.000000    69.000000    64.000000    79.000000    86.000000
# 50%     101.000000    81.000000    71.000000    91.000000   100.000000
# 75%     113.000000    90.000000    82.000000   104.000000   112.000000
# max     139.000000   151.000000   104.000000   130.000000   138.000000
#
#                V36
# count  5100.000000
# mean     79.492941
# std      13.707023
# min      29.000000
# 25%      68.000000
# 50%      81.000000
# 75%      90.000000
# max     147.000000
#
# [8 rows x 36 columns]

# %%
#data.loc[[100, 1000, 5000],:]

# %%
# To look at the data and since its big, I can use quartiles to highlight some values that are quite outliers

# %%
# example with feature V1, where quartile V1 = 64 (according to stats above)
v1_q1 = 64.0
display(data.loc[data.V1 < v1_q1, :].tail())
# Out:
#       V1  V2   V3  V4  V5  V6   V7  V8  V9  V10 ...   V27  V28  V29  V30  V31  \
# 5068  53  68   83  70  56  71   79  74  56   75 ...    88   74   52   79   92
# 5069  56  71   79  74  56  75   87  74  56   75 ...    92   74   56   75   92
# 5073  60  83  100  85  64  83   96  81  60   87 ...   100   85   59   87   96
# 5075  60  87  104  85  60  91  108  85  64   91 ...   104   89   70  104  117
# 5095  60  83  100  81  60  83   96  85  64   87 ...    96   85   66   91  104
#
#       V32  V33  V34  V35  V36
# 5068   74   56   75   92   74
# 5069   74   56   79   96   78
# 5073   81   66   96  104   89
# 5075   92   70  109  117   96
# 5095   92   66   87  108   89
#
# [5 rows x 36 columns]

# %%
# example with feature V3, where quartile V3 = 87 (according to stats above)
v3_q1 = 87.0
display(data.loc[data.V3 < v1_q1, :])
# here the feature is more interesting because there are less outliers
# Out:
#       V1  V2  V3  V4  V5  V6  V7  V8  V9  V10 ...   V27  V28  V29  V30  V31  \
# 35    55  54  63  46  59  51  67  46  59   51 ...    72   49   56   51   62
# 3307  63  66  62  57  63  63  65  53  63   66 ...    82   68   68   77   74
#
#       V32  V33  V34  V35  V36
# 35     45   56   54   65   45
# 3307   61   68   77   74   65
#
# [2 rows x 36 columns]

# %%
# TODO: Select three indices of your choice you wish to sample from the dataset
indices = [35, 3307, 5068]
samples = data[:1]

# Create a DataFrame of the chosen samples
# .reset_index(drop = True) resets the index from 0, 1 and 2 instead of 100, 200 and 300 
samples = pd.DataFrame(data.loc[indices], columns = data.columns).reset_index(drop = True)
print ("Chosen samples of wholesale customers dataset:")
display(samples)
# Out:
# Chosen samples of wholesale customers dataset:
#    V1  V2  V3  V4  V5  V6  V7  V8  V9  V10 ...   V27  V28  V29  V30  V31  V32  \
# 0  55  54  63  46  59  51  67  46  59   51 ...    72   49   56   51   62   45
# 1  63  66  62  57  63  63  65  53  63   66 ...    82   68   68   77   74   61
# 2  53  68  83  70  56  71  79  74  56   75 ...    88   74   52   79   92   74
#
#    V33  V34  V35  V36
# 0   56   54   65   45
# 1   68   77   74   65
# 2   56   75   92   74
#
# [3 rows x 36 columns]

# %%
# Import Seaborn, a very powerful library for Data Visualisation
import seaborn as sns

# Get the means 
mean_data = data.describe().loc['mean', :]

# Append means to the samples' data
samples_bar = samples.append(mean_data)

# Construct indices
samples_bar.index = indices + ['mean']

# Plot bar plot
samples_bar.plot(kind='bar', figsize=(14,8))

# %%
# First, calculate the percentile ranks of the whole dataset.
percentiles = data.rank(pct=True)

# Then, round it up, and multiply by 100
percentiles = 100*percentiles.round(decimals=3)

# Select the indices you chose from the percentiles dataframe
percentiles = percentiles.iloc[indices]

# Now, create the heat map using the seaborn library
sns.heatmap(percentiles, vmin=1, vmax=99, annot=True)

# %%
# Produce a scatter matrix for each pair of features in the data
pd.plotting.scatter_matrix(data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_corr(df,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    cax = ax.matshow(df, interpolation='nearest')
    ax.matshow(corr)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);


plot_corr(data)
# here we can see the different correlations between features. Interestingly, we find that 
# features seems to be correlated less and less every 4 features. Example: V1 correlated to V2,
# less correlated to V3, and less correlated to V4, highly correlated to V5, less with V6 
# and even less to V7 and V8, etc...

# %%
# Implementation : feature scaling

# %%
# TODO: Scale the data using the natural logarithm
log_data = np.log(data)

# TODO: Scale the sample data using the natural logarithm
log_samples = np.log(samples)

# Produce a scatter matrix for each pair of newly-transformed features
pd.scatter_matrix(log_data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');
# Out:
# /Users/ssicard/Library/Python/3.4/lib/python/site-packages/ipykernel_launcher.py:8: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead

# %%
# Display the log-transformed sample data
display(log_samples)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  4.007333  3.988984  4.143135  3.828641  4.077537  3.931826  4.204693
# 1  4.143135  4.189655  4.127134  4.043051  4.143135  4.143135  4.174387
# 2  3.970292  4.219508  4.418841  4.248495  4.025352  4.262680  4.369448
#
#          V8        V9       V10    ...          V27       V28       V29  \
# 0  3.828641  4.077537  3.931826    ...     4.276666  3.891820  4.025352
# 1  3.970292  4.143135  4.189655    ...     4.406719  4.219508  4.219508
# 2  4.304065  4.025352  4.317488    ...     4.477337  4.304065  3.951244
#
#         V30       V31       V32       V33       V34       V35       V36
# 0  3.931826  4.127134  3.806662  4.025352  3.988984  4.174387  3.806662
# 1  4.343805  4.304065  4.110874  4.219508  4.343805  4.304065  4.174387
# 2  4.369448  4.521789  4.304065  4.025352  4.317488  4.521789  4.304065
#
# [3 rows x 36 columns]

# %%
plot_corr(data)
plot_corr(log_data)

# %%
# there are not many changes in correlation after feature scaling

# %%
import itertools

# %%
# Select the indices for data points you wish to remove
outliers_lst  = []

# For each feature find the data points with extreme high or low values
for feature in log_data.columns:
    # TODO: Calculate Q1 (25th percentile of the data) for the given feature
    Q1 = np.percentile(log_data.loc[:, feature], 25)

    # TODO: Calculate Q3 (75th percentile of the data) for the given feature
    Q3 = np.percentile(log_data.loc[:, feature], 75)

    # TODO: Use the interquartile range to calculate an outlier step (1.5 times the interquartile range)
    step = 1.5 * (Q3 - Q1)

    # Display the outliers
    print ('Data points considered outliers for the feature {}:'.format(feature))

    # The tilde sign ~ means not
    # So here, we're finding any points outside of Q1 - step and Q3 + step
    outliers_rows = log_data.loc[~((log_data[feature] >= Q1 - step) & (log_data[feature] <= Q3 + step)), :]
    # display(outliers_rows)

    outliers_lst.append(list(outliers_rows.index))

outliers = list(itertools.chain.from_iterable(outliers_lst))

# List of unique outliers
# We use set()
# Sets are lists with no duplicate entries
uniq_outliers = list(set(outliers))

# List of duplicate outliers
dup_outliers = list(set([x for x in outliers if outliers.count(x) > 1]))

print ('Outliers list:\n', uniq_outliers)
print ('Length of outliers list:\n', len(uniq_outliers))

print ('Duplicate list:\n', dup_outliers)
print ('Length of duplicates list:\n', len(dup_outliers))

# Remove duplicate outliers
# Only 5 specified
good_data = log_data.drop(log_data.index[dup_outliers]).reset_index(drop = True)

# Original Data 
print ('Original shape of data:\n', data.shape)
# Processed Data
print ('New shape of data:\n', good_data.shape)
# Out:
# Data points considered outliers for the feature V1:
# Data points considered outliers for the feature V2:
# Data points considered outliers for the feature V3:
# Data points considered outliers for the feature V4:
# Data points considered outliers for the feature V5:
# Data points considered outliers for the feature V6:
# Data points considered outliers for the feature V7:
# Data points considered outliers for the feature V8:
# Data points considered outliers for the feature V9:
# Data points considered outliers for the feature V10:
# Data points considered outliers for the feature V11:
# Data points considered outliers for the feature V12:
# Data points considered outliers for the feature V13:
# Data points considered outliers for the feature V14:
# Data points considered outliers for the feature V15:
# Data points considered outliers for the feature V16:
# Data points considered outliers for the feature V17:
# Data points considered outliers for the feature V18:
# Data points considered outliers for the feature V19:
# Data points considered outliers for the feature V20:
# Data points considered outliers for the feature V21:
# Data points considered outliers for the feature V22:
# Data points considered outliers for the feature V23:
# Data points considered outliers for the feature V24:
# Data points considered outliers for the feature V25:
# Data points considered outliers for the feature V26:
# Data points considered outliers for the feature V27:
# Data points considered outliers for the feature V28:
# Data points considered outliers for the feature V29:
# Data points considered outliers for the feature V30:
# Data points considered outliers for the feature V31:
# Data points considered outliers for the feature V32:
# Data points considered outliers for the feature V33:
# Data points considered outliers for the feature V34:
# Data points considered outliers for the feature V35:
# Data points considered outliers for the feature V36:
# Outliers list:
#  [0, 1, 2, 3, 4, 5, 6, 7, 8, 2053, 10, 3083, 3084, 13, 11, 3082, 16, 17, 18, 19, 20, 21, 23, 24, 25, 26, 27, 28, 29, 31, 32, 33, 34, 35, 38, 39, 40, 41, 42, 43, 44, 45, 2606, 47, 2095, 50, 51, 54, 56, 57, 58, 59, 60, 12, 62, 63, 4674, 67, 68, 69, 66, 73, 114, 3701, 4727, 2681, 2682, 2176, 141, 1678, 1679, 1680, 1681, 158, 678, 4777, 4778, 196, 1733, 2247, 719, 2774, 2786, 2817, 276, 2337, 1313, 4387, 1828, 291, 2862, 2863, 2350, 2351, 1846, 2359, 2360, 1848, 1847, 328, 1352, 2388, 4436, 344, 350, 1887, 865, 362, 1903, 369, 3444, 387, 2948, 2949, 1413, 388, 389, 2443, 403, 3479, 418, 1956, 2473, 2474, 432, 3504, 2994, 4531, 2995, 969, 2512, 471, 3545, 2009, 3039, 3040, 4584, 4585, 4586, 2548, 2549, 2550, 3582]
# Length of outliers list:
#  143
# Duplicate list:
#  [0, 1, 2, 3, 4, 5, 6, 7, 8, 388, 10, 3083, 1680, 13, 12, 1679, 16, 17, 18, 19, 20, 21, 403, 23, 24, 3479, 26, 27, 28, 29, 31, 32, 33, 35, 4387, 38, 39, 40, 41, 42, 2473, 44, 45, 2862, 47, 3504, 2350, 50, 2994, 2095, 54, 2359, 56, 57, 1847, 59, 60, 62, 63, 66, 68, 69, 1352, 73, 719, 344, 3545, 3039, 4585, 114, 3444, 2549, 2682, 3582]
# Length of duplicates list:
#  74
# Original shape of data:
#  (5100, 36)
# New shape of data:
#  (5026, 36)
