# %%
import matplotlib.pyplot as plt
import pandas as pd
from numpy import genfromtxt
from sklearn.decomposition import PCA as sklearnPCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.datasets.samples_generator import make_blobs

from pandas.tools.plotting import parallel_coordinates

# %%
cols = ["V1","V2","V3","V4","V5","V6","V7","V8","V9","V10","V11","V12","V13","V14","V15","V16","V17","V18","V19","V20","V21","V22","V23","V24","V25","V26","V27","V28","V29","V30","V31","V32","V33","V34","V35","V36"]

# %%
data = pd.read_csv('mydata.csv', names=cols)
data = data[1:]

# %%
#data
#y = data['V1']
X = data.ix[:]

# %%
pca = sklearnPCA(n_components=36) #2-dimensional PCA
transformed = pd.DataFrame(pca.fit_transform(X))

# %%
plt.scatter(transformed[y==1][0], transformed[y==1][1], label='Class 1', c='red')
plt.scatter(transformed[y==2][0], transformed[y==2][1], label='Class 2', c='blue')
plt.scatter(transformed[y==3][0], transformed[y==3][1], label='Class 3', c='lightgreen')

plt.legend()
plt.show()

# %%
plt.scatter(X[y==1]['V1'], X[y==1]['V2'], label='V1', c='red') 
plt.scatter(X[y==2]['V1'], X[y==2]['V2'], label='V2', c='blue')
plt.scatter(X[y==3]['V1'], X[y==3]['V2'], label='V3', c='lightgreen')

plt.legend()
plt.xlabel('V1')
plt.ylabel('V2')
plt.axis([25, 120, 25, 150])
plt.show()

# %%
# Concat classes with the normalized data
data_norm = pd.concat([X[cols], y], axis=1)

# Perform parallel coordinate plot
parallel_coordinates(data_norm, 'V1')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-7180b5c07cd3> in <module>()
#       1 # Concat classes with the normalized data
# ----> 2 data_norm = pd.concat([X[cols], y], axis=1)
#       3
#       4 # Perform parallel coordinate plot
#       5 parallel_coordinates(data_norm, 'V1')
#
# ~/Library/Python/3.4/lib/python/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     204                        keys=keys, levels=levels, names=names,
#     205                        verify_integrity=verify_integrity,
# --> 206                        copy=copy)
#     207     return op.get_result()
#     208
#
# ~/Library/Python/3.4/lib/python/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     261         for obj in objs:
#     262             if not isinstance(obj, NDFrame):
# --> 263                 raise TypeError("cannot concatenate a non-NDFrame object")
#     264
#     265             # consolidate
#
# TypeError: cannot concatenate a non-NDFrame object

# %%
plt.scatter(X[:,1], X[:,2])
plt.show()
#fig, ax = plt.subplots(figsize=(200, 200))
#ax.scatter(X[:,0], X[:,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-7f4946f3e423> in <module>()
# ----> 1 plt.scatter(data[:1], data[:2])
#       2 plt.show()
#       3 #fig, ax = plt.subplots(figsize=(200, 200))
#       4 #ax.scatter(X[:,0], X[:,1])
#
# ~/Library/Python/3.4/lib/python/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3432                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3433                          linewidths=linewidths, verts=verts,
# -> 3434                          edgecolors=edgecolors, data=data, **kwargs)
#    3435     finally:
#    3436         ax._hold = washold
#
# ~/Library/Python/3.4/lib/python/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ~/Library/Python/3.4/lib/python/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3962         y = np.ma.ravel(y)
#    3963         if x.size != y.size:
# -> 3964             raise ValueError("x and y must be the same size")
#    3965
#    3966         if s is None:
#
# ValueError: x and y must be the same size
